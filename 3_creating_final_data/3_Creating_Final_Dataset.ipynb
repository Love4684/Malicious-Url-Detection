# %% [markdown]
# # Creating Final Dataset and save in to Comma Seperated Value(.csv) Files

# %% [markdown]
# ## Creating Final Data Set
# In here, we concatenate phishing1.csv, phishing2.csv, legitimate1.csv and legitimate1.csv and make a final datatset.csv file

# %% [markdown]
# Creating DataFrame for Uploaded Phishing URLs Files

# %%
#importing required packages for this module
import pandas as pd

# %%
phishing = pd.read_csv("final-phish_features.csv")
phishing
# Out:
#                                   Domain  Have_IP  ...  Web_Forwards  Label
# 0                    mail.bacritkita.com        0  ...             0      1
# 1                   cr.mufg.jp.wlupi.com        0  ...             1      1
# 2                        ee.uk.trg87.com        0  ...             0      1
# 3                                 bit.ly        0  ...             0      1
# 4                   lloyd-reviewdata.com        0  ...             0      1
# ...                                  ...      ...  ...           ...    ...
# 4995                      puffing.com.pk        0  ...             0      1
# 4996                  track.drerries.com        0  ...             0      1
# 4997  nocontent-qqhrshfg.velocityhub.com        0  ...             0      1
# 4998                  w6634s.webwave.dev        0  ...             0      1
# 4999                    forms.office.com        0  ...             0      1
#
# [5000 rows x 18 columns]

# %% [markdown]
# Creating DataFrame for Uploaded Phishing URLs Files

# %%
legitimate = pd.read_csv("legitimate_features.csv")
legitimate
# Out:
#                  Domain  Have_IP  Have_At  ...  Right_Click  Web_Forwards  Label
# 0      graphicriver.net        0        0  ...            1             0      0
# 1             ecnavi.jp        0        0  ...            1             0      0
# 2          hubpages.com        0        0  ...            1             0      0
# 3       extratorrent.cc        0        0  ...            1             0      0
# 4         icicibank.com        0        0  ...            1             0      0
# ...                 ...      ...      ...  ...          ...           ...    ...
# 4995      getpocket.com        0        0  ...            1             0      0
# 4996             olx.ro        0        0  ...            1             1      0
# 4997         medium.com        0        1  ...            1             0      0
# 4998     thenextweb.com        0        0  ...            1             0      0
# 4999  smallseotools.com        0        0  ...            1             0      0
#
# [5000 rows x 18 columns]

# %% [markdown]
# ## **5. Final Dataset**
# In the above section we formed two dataframes of legitimate & phishing URL features. Now, we will combine them to a single dataframe and export the data to csv file for the Machine Learning training done in other notebook.

# %%
#Concatenating the dataframes into one 
urldata = pd.concat([legitimate, phishing]).reset_index(drop=True)
urldata
# Out:
#                                   Domain  Have_IP  ...  Web_Forwards  Label
# 0                       graphicriver.net        0  ...             0      0
# 1                              ecnavi.jp        0  ...             0      0
# 2                           hubpages.com        0  ...             0      0
# 3                        extratorrent.cc        0  ...             0      0
# 4                          icicibank.com        0  ...             0      0
# ...                                  ...      ...  ...           ...    ...
# 9995                      puffing.com.pk        0  ...             0      1
# 9996                  track.drerries.com        0  ...             0      1
# 9997  nocontent-qqhrshfg.velocityhub.com        0  ...             0      1
# 9998                  w6634s.webwave.dev        0  ...             0      1
# 9999                    forms.office.com        0  ...             0      1
#
# [10000 rows x 18 columns]

# %%
# Storing the data in CSV file
urldata.to_csv('Final_dataset.csv', index=False)

# %% [markdown]
# ### Love kumar [Linked In](https://www.linkedin.com/in/love4684/)
